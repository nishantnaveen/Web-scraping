# %% [markdown]
# # Scraping former indian president and their year of tenure

# %%
import requests   
import bs4 
from bs4 import BeautifulSoup

link= requests.get('https://presidentofindia.nic.in/former-presidents.htm')
link
soup=BeautifulSoup(link.content)

president_name=[]
term=[]
for i in soup.find_all('div', class_="presidentListing"):
    
    president_name.append(i.text.split('\n')[1].split('(')[0])
    term.append(i.text.split('\n')[2].split(':')[1])
# print(f'The name of all the respected former presidents are {president_name},"\n"')
# print(f'The term of office respectively are {term}')
# term=[]
# for i in soup.find_all('span', class_="terms"):
#     term.append(i.text.replace('\n', ""))
# term


import pandas as pd
df=pd.DataFrame({"President's name":president_name, 'Term': term})
df
# Out:
#                  President's name  \
# 0           Shri Ram Nath Kovind
# 1          Shri Pranab Mukherjee
# 2   Smt Pratibha Devisingh Patil
# 3         DR. A.P.J. Abdul Kalam
# 4           Shri K. R. Narayanan
# 5        Dr Shankar Dayal Sharma
# 6            Shri R Venkataraman
# 7               Giani Zail Singh
# 8      Shri Neelam Sanjiva Reddy
# 9       Dr. Fakhruddin Ali Ahmed
# 10  Shri Varahagiri Venkata Giri
# 11              Dr. Zakir Husain
# 12  Dr. Sarvepalli Radhakrishnan
# 13           Dr. Rajendra Prasad
#
#                                                  Term
# 0                     25 July, 2017 to 25 July, 2022
# 1                     25 July, 2012 to 25 July, 2017
# 2                     25 July, 2007 to 25 July, 2012
# 3                     25 July, 2002 to 25 July, 2007
# 4                     25 July, 1997 to 25 July, 2002
# 5                     25 July, 1992 to 25 July, 1997
# 6                     25 July, 1987 to 25 July, 1992
# ...

# %%
# Out:
# The name of all the respected former presidents are ['Shri Ram Nath Kovind ', 'Shri Pranab Mukherjee ', 'Smt Pratibha Devisingh Patil ', 'DR. A.P.J. Abdul Kalam ', 'Shri K. R. Narayanan ', 'Dr Shankar Dayal Sharma ', 'Shri R Venkataraman ', 'Giani Zail Singh ', 'Shri Neelam Sanjiva Reddy ', 'Dr. Fakhruddin Ali Ahmed ', 'Shri Varahagiri Venkata Giri ', 'Dr. Zakir Husain ', 'Dr. Sarvepalli Radhakrishnan ', 'Dr. Rajendra Prasad '],"
# "
# ...

# %%
# Out:
#                  President's name  \
# 0           Shri Ram Nath Kovind
# 1          Shri Pranab Mukherjee
# 2   Smt Pratibha Devisingh Patil
# 3         DR. A.P.J. Abdul Kalam
# 4           Shri K. R. Narayanan
# 5        Dr Shankar Dayal Sharma
# 6            Shri R Venkataraman
# 7               Giani Zail Singh
# 8      Shri Neelam Sanjiva Reddy
# 9       Dr. Fakhruddin Ali Ahmed
# 10  Shri Varahagiri Venkata Giri
# 11              Dr. Zakir Husain
# 12  Dr. Sarvepalli Radhakrishnan
# 13           Dr. Rajendra Prasad
#
#                                                  Term
# 0                     25 July, 2017 to 25 July, 2022
# 1                     25 July, 2012 to 25 July, 2017
# 2                     25 July, 2007 to 25 July, 2012
# 3                     25 July, 2002 to 25 July, 2007
# 4                     25 July, 1997 to 25 July, 2002
# 5                     25 July, 1992 to 25 July, 1997
# 6                     25 July, 1987 to 25 July, 1992
# ...
